# %% [markdown]
# # **KNN SAMPLE PROGRAM**

# %%
x=[[10,9],[1,4],[10,1],[7,10],[3,10],[1,1],[8,5],[3,7],[3,6],[7,3]]
y=['fruit','protein','fruit','vegetable','vegetable','protein','fruit','vegetable','protein','fruit']

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier=KNeighborsClassifier(n_neighbors=3)
classifier.fit(x,y)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
tomato=[[6,4]]
print(classifier.predict(tomato))
# Out:
# ['fruit']

# %%
carrot=[[4,9]]
print(classifier.predict(carrot))
# Out:
# ['vegetable']

# %% [markdown]
# # **KNN SAMPLE PROGRAM2**

# %%
x=[[8,6],[5,6],[7,3],[6,9]]
y=['outstanding','good','good','outstanding']

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier=KNeighborsClassifier(n_neighbors=3)
classifier.fit(x,y)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
stud=[[5,7]]
print(classifier.predict(stud))
# Out:
# ['outstanding']

# %% [markdown]
# # **KNN PROGRAM 2**

# %%
x=[[167,51],[182,62],[176,69],[173,64],[172,65],[174,56],[169,58],[173,57],[170,55],[169,53]]
y=['underweight','normal','normal','normal','normal','underweight','normal','normal','normal','underweight']

# %%
from sklearn.neighbors import KNeighborsClassifier
cls1=KNeighborsClassifier(n_neighbors=1)
cls1.fit(x,y)

cls2=KNeighborsClassifier(n_neighbors=3)
cls2.fit(x,y)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
new1=[[172,57]]
print(cls1.predict(new1))
# Out:
# ['normal']

# %%
new2=[[172,57]]
print(cls2.predict(new2))
# Out:
# ['normal']
