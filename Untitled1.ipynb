# %%
x=[[8,6],[5,6],[7,3],[6,9]]
y=['outstandng','good','good','outstanding']
from sklearn.neighbors import KNeighborsClassifier
classifier=KNeighborsClassifier(n_neighbors=3)
classifier.fit(x,y)
stud=[[5,7]]
print(classifier.predict(stud))
# Out:
# ['good']
